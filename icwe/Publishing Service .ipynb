# %% [markdown]
# # Publishing Service

# %%
%log debug
%publisher http://docker.for.mac.localhost:8181/csparql
# Out:
# Logging set to DEBUG
# Publisher set to: http://docker.for.mac.localhost:8181/csparql

# %% [markdown]
# ## Vocalize the stream using a Publisher

# %% [markdown]
# ### We take the default description, which creates only the skeleton  Descriptor + Stream + [Endpoint]

# %%
%display diagram
REGISTER STREAM s2 SOURCE <ws://localhost:4040/stream1>
# Out:
# Display: svg

# %% [markdown]
# ## Let's take a look to the streams, in another form

# %%
%display table
DESCRIBE STREAM <http://docker.for.mac.localhost:9191/triplewave/streams/s2>
# Out:
# Display: table
# <div class="krn-spql"><table><tr class=hdr><th>subject</th>
# <th>predicate</th>
# <th>object</th></tr><tr class=odd><td class=val>Nb9a83b8833e947dda7069aed3d9a67fa</td>
# <td class=val><a href="http://www.w3.org/1999/02/22-rdf-syntax-ns#type" target="_other">http://www.w3.org/1999/02/22-rdf-syntax-ns#type</a></td>
# <td class=val><a href="http://w3id.org/rsp/vocals#StreamDescriptor" target="_other">http://w3id.org/rsp/vocals#StreamDescriptor</a></td></tr><tr class=even><td class=val><a href="http://localhost:8181/csparql/streams/s2" target="_other">http://localhost:8181/csparql/streams/s2</a></td>
# <td class=val><a href="http://www.w3.org/1999/02/22-rdf-syntax-ns#type" target="_other">http://www.w3.org/1999/02/22-rdf-syntax-ns#type</a></td>
# <td class=val><a href="http://w3id.org/rsp/vocals#RDFStream" target="_other">http://w3id.org/rsp/vocals#RDFStream</a></td></tr><tr class=odd><td class=val>Nfa4dfdc15d624085ba5e8baa20686a8b</td>
# ...

# %%
#open a websocket apart to show two streams
